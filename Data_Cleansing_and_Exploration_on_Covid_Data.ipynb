# %% [markdown]
# # **Covid-19 Data Exploration using python**

# %%
from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# %cd /content/gdrive/MyDrive/SLIIT/Data_Science/Data Analyst Projects/Sample Projects
# Out:
# /content/gdrive/MyDrive/SLIIT/Data_Science/Data Analyst Projects/Sample Projects

# %%
import pandas as pd

#import the csv while parsing the dates (if the data type of date is not in datetime, this will change it to that)
df = pd.read_csv('owid-covid-data.csv', parse_dates=True)

#then we will see what are the issues to be resolved carefully

# %%
#Let's try to get an overall understanding of the dataset now
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365398 entries, 0 to 365397
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    365398 non-null  object
#  1   continent                                   348008 non-null  object
#  2   location                                    365398 non-null  object
#  3   date                                        365398 non-null  object
#  4   total_cases                                 327216 non-null  float64
#  5   new_cases                                   355673 non-null  float64
#  6   new_cases_smoothed                          354414 non-null  float64
#  7   total_deaths                                305512 non-null  float64
#  8   new_deaths                                  355720 non-null  float64
#  9   new_deaths_smoothed                         354490 non-null  float64
#  10  total_cases_per_million                     327216 non-null  float64
#  11  new_cases_per_million                       355673 non-null  float64
#  12  new_cases_smoothed_per_million              354414 non-null  float64
#  13  total_deaths_per_million                    305512 non-null  float64
#  14  new_deaths_per_million                      355720 non-null  float64
#  15  new_deaths_smoothed_per_million             354490 non-null  float64
#  16  reproduction_rate                           184817 non-null  float64
#  17  icu_patients                                38037 non-null   float64
#  18  icu_patients_per_million                    38037 non-null   float64
#  19  hosp_patients                               39497 non-null   float64
#  20  hosp_patients_per_million                   39497 non-null   float64
#  21  weekly_icu_admissions                       10387 non-null   float64
#  22  weekly_icu_admissions_per_million           10387 non-null   float64
#  23  weekly_hosp_admissions                      23664 non-null   float64
#  24  weekly_hosp_admissions_per_million          23664 non-null   float64
#  25  total_tests                                 79387 non-null   float64
#  26  new_tests                                   75403 non-null   float64
#  27  total_tests_per_thousand                    79387 non-null   float64
#  28  new_tests_per_thousand                      75403 non-null   float64
#  29  new_tests_smoothed                          103965 non-null  float64
#  30  new_tests_smoothed_per_thousand             103965 non-null  float64
#  31  positive_rate                               95927 non-null   float64
#  32  tests_per_case                              94348 non-null   float64
#  33  tests_units                                 106788 non-null  object
#  34  total_vaccinations                          80562 non-null   float64
#  35  people_vaccinated                           77105 non-null   float64
#  36  people_fully_vaccinated                     73817 non-null   float64
#  37  total_boosters                              48730 non-null   float64
#  38  new_vaccinations                            66514 non-null   float64
#  39  new_vaccinations_smoothed                   184717 non-null  float64
#  40  total_vaccinations_per_hundred              80562 non-null   float64
#  41  people_vaccinated_per_hundred               77105 non-null   float64
#  42  people_fully_vaccinated_per_hundred         73817 non-null   float64
#  43  total_boosters_per_hundred                  48730 non-null   float64
#  44  new_vaccinations_smoothed_per_million       184717 non-null  float64
#  45  new_people_vaccinated_smoothed              184443 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  184443 non-null  float64
#  47  stringency_index                            197651 non-null  float64
#  48  population_density                          310351 non-null  float64
#  49  median_age                                  288548 non-null  float64
#  50  aged_65_older                               278517 non-null  float64
#  51  aged_70_older                               285654 non-null  float64
#  52  gdp_per_capita                              282858 non-null  float64
#  53  extreme_poverty                             182347 non-null  float64
#  54  cardiovasc_death_rate                       283546 non-null  float64
#  55  diabetes_prevalence                         297980 non-null  float64
#  56  female_smokers                              212742 non-null  float64
#  57  male_smokers                                209848 non-null  float64
#  58  handwashing_facilities                      138918 non-null  float64
#  59  hospital_beds_per_thousand                  250364 non-null  float64
#  60  life_expectancy                             336299 non-null  float64
#  61  human_development_index                     274825 non-null  float64
#  62  population                                  365398 non-null  float64
#  63  excess_mortality_cumulative_absolute        12211 non-null   float64
#  64  excess_mortality_cumulative                 12211 non-null   float64
#  65  excess_mortality                            12211 non-null   float64
#  66  excess_mortality_cumulative_per_million     12211 non-null   float64
# dtypes: float64(62), object(5)
# memory usage: 186.8+ MB

# %% [markdown]
# ## **It seems, the data type of 'date' column hasn't changed. So we will have to do it manually again.**
#
# ## **Also it appears that the 'continent' feature has some null values. We will have to check those & take a decision on them.**
#
# ## **cases, deaths, tests, vaccination data can include null values. So, that's not a concern.**

# %%
#Converting object type into datetime
df['date'] = pd.to_datetime(df['date'])
df['date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 365398 entries, 0 to 365397
# Series name: date
# Non-Null Count   Dtype
# --------------   -----
# 365398 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 2.8 MB

# %%
#let's explore the null values of 'continent' field
df_new = df.loc[df['continent'].isnull()]
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17390 entries, 1447 to 361056
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   iso_code                                    17390 non-null  object
#  1   continent                                   0 non-null      object
#  2   location                                    17390 non-null  object
#  3   date                                        17390 non-null  datetime64[ns]
#  4   total_cases                                 17146 non-null  float64
#  5   new_cases                                   17364 non-null  float64
#  6   new_cases_smoothed                          17304 non-null  float64
#  7   total_deaths                                16996 non-null  float64
#  8   new_deaths                                  17364 non-null  float64
#  9   new_deaths_smoothed                         17304 non-null  float64
#  10  total_cases_per_million                     17146 non-null  float64
#  11  new_cases_per_million                       17364 non-null  float64
#  12  new_cases_smoothed_per_million              17304 non-null  float64
#  13  total_deaths_per_million                    16996 non-null  float64
#  14  new_deaths_per_million                      17364 non-null  float64
#  15  new_deaths_smoothed_per_million             17304 non-null  float64
#  16  reproduction_rate                           1076 non-null   float64
#  17  icu_patients                                0 non-null      float64
#  18  icu_patients_per_million                    0 non-null      float64
#  19  hosp_patients                               0 non-null      float64
#  20  hosp_patients_per_million                   0 non-null      float64
#  21  weekly_icu_admissions                       0 non-null      float64
#  22  weekly_icu_admissions_per_million           0 non-null      float64
#  23  weekly_hosp_admissions                      0 non-null      float64
#  24  weekly_hosp_admissions_per_million          0 non-null      float64
#  25  total_tests                                 0 non-null      float64
#  26  new_tests                                   0 non-null      float64
#  27  total_tests_per_thousand                    0 non-null      float64
#  28  new_tests_per_thousand                      0 non-null      float64
#  29  new_tests_smoothed                          0 non-null      float64
#  30  new_tests_smoothed_per_thousand             0 non-null      float64
#  31  positive_rate                               0 non-null      float64
#  32  tests_per_case                              0 non-null      float64
#  33  tests_units                                 0 non-null      object
#  34  total_vaccinations                          12828 non-null  float64
#  35  people_vaccinated                           12828 non-null  float64
#  36  people_fully_vaccinated                     12642 non-null  float64
#  37  total_boosters                              11676 non-null  float64
#  38  new_vaccinations                            12784 non-null  float64
#  39  new_vaccinations_smoothed                   12784 non-null  float64
#  40  total_vaccinations_per_hundred              12828 non-null  float64
#  41  people_vaccinated_per_hundred               12828 non-null  float64
#  42  people_fully_vaccinated_per_hundred         12642 non-null  float64
#  43  total_boosters_per_hundred                  11676 non-null  float64
#  44  new_vaccinations_smoothed_per_million       12784 non-null  float64
#  45  new_people_vaccinated_smoothed              12784 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  12784 non-null  float64
#  47  stringency_index                            0 non-null      float64
#  48  population_density                          1451 non-null   float64
#  49  median_age                                  1451 non-null   float64
#  50  aged_65_older                               1451 non-null   float64
#  51  aged_70_older                               1451 non-null   float64
#  52  gdp_per_capita                              1451 non-null   float64
#  53  extreme_poverty                             1451 non-null   float64
#  54  cardiovasc_death_rate                       1451 non-null   float64
#  55  diabetes_prevalence                         1451 non-null   float64
#  56  female_smokers                              1451 non-null   float64
#  57  male_smokers                                1451 non-null   float64
#  58  handwashing_facilities                      1451 non-null   float64
#  59  hospital_beds_per_thousand                  1451 non-null   float64
#  60  life_expectancy                             1451 non-null   float64
#  61  human_development_index                     1451 non-null   float64
#  62  population                                  17390 non-null  float64
#  63  excess_mortality_cumulative_absolute        0 non-null      float64
#  64  excess_mortality_cumulative                 0 non-null      float64
#  65  excess_mortality                            0 non-null      float64
#  66  excess_mortality_cumulative_per_million     0 non-null      float64
# dtypes: datetime64[ns](1), float64(62), object(4)
# memory usage: 9.0+ MB

# %%
#17390 entries out of 365000 entries is a small portion. SO let's get rid of it.
df.dropna(subset='continent', inplace=True) #removing all the records were null values exist in 'continent' field
df['continent'].isnull().sum() #checing whether there are any null values left in continent field
# Out:
# 0

# %%
df.head()
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan 2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan 2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan 2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan 2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0           NaN                  37.746                         0.5
# 1           NaN                  37.746                         0.5
# 2           NaN                  37.746                         0.5
# 3           NaN                  37.746                         0.5
# 4           NaN                  37.746                         0.5
#
#    life_expectancy  human_development_index  population  \
# 0            64.83                    0.511  41128772.0
# 1            64.83                    0.511  41128772.0
# 2            64.83                    0.511  41128772.0
# 3            64.83                    0.511  41128772.0
# 4            64.83                    0.511  41128772.0
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# ## **To make things easy let's devide this into 2 datframes,covid deaths and vaccinations.**

# %%
df_deaths = df.iloc[:,:25]
df.head()
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan 2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan 2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan 2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan 2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0           NaN                  37.746                         0.5
# 1           NaN                  37.746                         0.5
# 2           NaN                  37.746                         0.5
# 3           NaN                  37.746                         0.5
# 4           NaN                  37.746                         0.5
#
#    life_expectancy  human_development_index  population  \
# 0            64.83                    0.511  41128772.0
# 1            64.83                    0.511  41128772.0
# 2            64.83                    0.511  41128772.0
# 3            64.83                    0.511  41128772.0
# 4            64.83                    0.511  41128772.0
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
df_deaths.head()
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan 2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan 2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan 2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan 2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# 0                              NaN                NaN           NaN
# 1                              NaN                NaN           NaN
# 2                              NaN                NaN           NaN
# 3                              NaN                NaN           NaN
# 4                              NaN                NaN           NaN
#
#    icu_patients_per_million  hosp_patients  hosp_patients_per_million  \
# 0                       NaN            NaN                        NaN
# 1                       NaN            NaN                        NaN
# 2                       NaN            NaN                        NaN
# 3                       NaN            NaN                        NaN
# 4                       NaN            NaN                        NaN
#
#    weekly_icu_admissions  weekly_icu_admissions_per_million  \
# 0                    NaN                                NaN
# 1                    NaN                                NaN
# 2                    NaN                                NaN
# 3                    NaN                                NaN
# 4                    NaN                                NaN
#
#    weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 0                     NaN                                 NaN
# 1                     NaN                                 NaN
# 2                     NaN                                 NaN
# 3                     NaN                                 NaN
# 4                     NaN                                 NaN
#
# [5 rows x 25 columns]

# %%
df_vaccinations = df.iloc[:, 25:]
df_vaccinations.head()
# Out:
#    total_tests  new_tests  total_tests_per_thousand  new_tests_per_thousand  \
# 0          NaN        NaN                       NaN                     NaN
# 1          NaN        NaN                       NaN                     NaN
# 2          NaN        NaN                       NaN                     NaN
# 3          NaN        NaN                       NaN                     NaN
# 4          NaN        NaN                       NaN                     NaN
#
#    new_tests_smoothed  new_tests_smoothed_per_thousand  positive_rate  \
# 0                 NaN                              NaN            NaN
# 1                 NaN                              NaN            NaN
# 2                 NaN                              NaN            NaN
# 3                 NaN                              NaN            NaN
# 4                 NaN                              NaN            NaN
#
#    tests_per_case tests_units  total_vaccinations  ...  male_smokers  \
# 0             NaN         NaN                 NaN  ...           NaN
# 1             NaN         NaN                 NaN  ...           NaN
# 2             NaN         NaN                 NaN  ...           NaN
# 3             NaN         NaN                 NaN  ...           NaN
# 4             NaN         NaN                 NaN  ...           NaN
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                  37.746                         0.5            64.83
# 1                  37.746                         0.5            64.83
# 2                  37.746                         0.5            64.83
# 3                  37.746                         0.5            64.83
# 4                  37.746                         0.5            64.83
#
#    human_development_index  population  excess_mortality_cumulative_absolute  \
# 0                    0.511  41128772.0                                   NaN
# 1                    0.511  41128772.0                                   NaN
# 2                    0.511  41128772.0                                   NaN
# 3                    0.511  41128772.0                                   NaN
# 4                    0.511  41128772.0                                   NaN
#
#    excess_mortality_cumulative  excess_mortality  \
# 0                          NaN               NaN
# 1                          NaN               NaN
# 2                          NaN               NaN
# 3                          NaN               NaN
# 4                          NaN               NaN
#
#    excess_mortality_cumulative_per_million
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# ## **Well, I need the population column inside df_deaths for further data exploration. So lets add that column.**

# %%
df_deaths['population'] = df['population']

# %%
df_deaths[['continent','location','population', 'total_cases', 'total_deaths']].sort_values(by=['continent', 'location'], ascending=[True, True])
# Out:
#             continent   location  population  total_cases  total_deaths
# 4341           Africa    Algeria  44903228.0          NaN           NaN
# 4342           Africa    Algeria  44903228.0          NaN           NaN
# 4343           Africa    Algeria  44903228.0          NaN           NaN
# 4344           Africa    Algeria  44903228.0          NaN           NaN
# 4345           Africa    Algeria  44903228.0          NaN           NaN
# ...               ...        ...         ...          ...           ...
# 355508  South America  Venezuela  28301700.0     552695.0        5856.0
# 355509  South America  Venezuela  28301700.0     552695.0        5856.0
# 355510  South America  Venezuela  28301700.0     552695.0        5856.0
# 355511  South America  Venezuela  28301700.0     552695.0        5856.0
# 355512  South America  Venezuela  28301700.0     552695.0        5856.0
#
# [348008 rows x 5 columns]

# %% [markdown]
# ## **We can get a better understanding of cases & deaths if we take them as a percentage of the popultion of that respective country.**

# %%
df_deaths['cases_percentage'] = (df_deaths['total_cases']/df_deaths['population'])*100
df_deaths['death_percentage'] = (df_deaths['total_deaths']/df_deaths['population'])*100

df_deaths[['continent', 'location', 'population', 'total_cases', 'cases_percentage', 'total_deaths', 'death_percentage']].sort_values(by=['continent', 'location'], ascending=[True, True]).reset_index()
# Out:
#          index      continent   location  population  total_cases  \
# 0         4341         Africa    Algeria  44903228.0          NaN
# 1         4342         Africa    Algeria  44903228.0          NaN
# 2         4343         Africa    Algeria  44903228.0          NaN
# 3         4344         Africa    Algeria  44903228.0          NaN
# 4         4345         Africa    Algeria  44903228.0          NaN
# ...        ...            ...        ...         ...          ...
# 348003  355508  South America  Venezuela  28301700.0     552695.0
# 348004  355509  South America  Venezuela  28301700.0     552695.0
# 348005  355510  South America  Venezuela  28301700.0     552695.0
# 348006  355511  South America  Venezuela  28301700.0     552695.0
# 348007  355512  South America  Venezuela  28301700.0     552695.0
#
#         cases_percentage  total_deaths  death_percentage
# 0                    NaN           NaN               NaN
# 1                    NaN           NaN               NaN
# 2                    NaN           NaN               NaN
# 3                    NaN           NaN               NaN
# 4                    NaN           NaN               NaN
# ...                  ...           ...               ...
# 348003          1.952869        5856.0          0.020691
# 348004          1.952869        5856.0          0.020691
# 348005          1.952869        5856.0          0.020691
# 348006          1.952869        5856.0          0.020691
# 348007          1.952869        5856.0          0.020691
#
# [348008 rows x 8 columns]
# Warning: total number of rows (348008) exceeds max_rows (20000). Limiting to first (20000) rows.

# %% [markdown]
# ## **We can group it by location & check which countries have the highest number of deaths & cases.**

# %%
df_deaths[['location', 'total_cases', 'total_deaths']].groupby(['location']).aggregate({'total_cases':'max', 'total_deaths':'max'}).sort_values(by=['total_deaths'], ascending=[False]).reset_index()
# Out:
#            location  total_cases  total_deaths
# 0     United States  103436829.0     1144877.0
# 1            Brazil   37519960.0      702116.0
# 2             India   45004816.0      533316.0
# 3            Russia   23479653.0      400771.0
# 4            Mexico    7702582.0      334938.0
# ..              ...          ...           ...
# 238         Tokelau         80.0           NaN
# 239    Turkmenistan          NaN           NaN
# 240         Vatican         26.0           NaN
# 241           Wales          NaN           NaN
# 242  Western Sahara          NaN           NaN
#
# [243 rows x 3 columns]

# %% [markdown]
# ## **It would be better if we check the deaths, cases percentage to find the countries that have heavily impacted by covid.**

# %%
df_deaths[['location', 'cases_percentage', 'death_percentage']].groupby('location').aggregate({'cases_percentage':'max', 'death_percentage':'max'}).sort_values(by=['cases_percentage'], ascending=False)
# Out:
#                 cases_percentage  death_percentage
# location
# San Marino             75.072722          0.373998
# Cyprus                 73.755451          0.152231
# Brunei                 71.544225          0.037416
# Austria                68.026259          0.252069
# South Korea            66.720706          0.069349
# ...                          ...               ...
# Scotland                     NaN               NaN
# Taiwan                       NaN               NaN
# Turkmenistan                 NaN               NaN
# Wales                        NaN               NaN
# Western Sahara               NaN               NaN
#
# [243 rows x 2 columns]

# %% [markdown]
# ## **It's suprising that USA is not appearing in the top 25 countries. When I looked at this data back in 2021, it was at the top of the list. Lets try to filter this dataset by year & check how these ranks have changed over the years.**

# %%
df_deaths.loc[df_deaths['location']=='United States', ['location', 'total_cases', 'population', 'cases_percentage', 'death_percentage']].groupby('location').aggregate({'total_cases':'max', 'cases_percentage':'max', 'population':'max', 'death_percentage':'max'})
# Out:
#                total_cases  cases_percentage   population  death_percentage
# location
# United States  103436829.0         30.576391  338289856.0          0.338431

# %%
df_deaths.loc[df_deaths['date'].dt.year.isin([2020, 2021]), ['location', 'death_percentage','cases_percentage']].groupby('location').agg({'death_percentage': 'max','cases_percentage': 'max'}).sort_values(by=['cases_percentage'], ascending=False)
# Out:
#               death_percentage  cases_percentage
# location
# Andorra               0.175344         28.959333
# Gibraltar             0.306026         26.113168
# Montenegro            0.362951         25.197662
# Georgia               0.368552         24.963806
# San Marino            0.293856         24.490947
# ...                        ...               ...
# Taiwan                     NaN               NaN
# Tokelau                    NaN               NaN
# Turkmenistan               NaN               NaN
# Tuvalu                     NaN               NaN
# Wales                      NaN               NaN
#
# [242 rows x 2 columns]

# %% [markdown]
# ## **As I expected, USA is appearing among top 25 countries with highest percentage of cases.**
#
# We can check the countries with the highest death percentage as well.

# %%
df_deaths[['location', 'death_percentage', 'cases_percentage']].groupby('location').aggregate({'cases_percentage':'max', 'death_percentage':'max'}).sort_values(by=['death_percentage'], ascending=False)
# Out:
#                         cases_percentage  death_percentage
# location
# Peru                           13.275056          0.650710
# Bulgaria                       19.395897          0.568258
# Bosnia and Herzegovina         12.476860          0.506382
# Hungary                        22.274509          0.490343
# North Macedonia                16.713890          0.475734
# ...                                  ...               ...
# Tokelau                         4.226096               NaN
# Turkmenistan                         NaN               NaN
# Vatican                         3.217822               NaN
# Wales                                NaN               NaN
# Western Sahara                       NaN               NaN
#
# [243 rows x 2 columns]

# %%
df_deaths.loc[df_deaths['date'].dt.year.isin([2020, 2021]), ['location', 'death_percentage','cases_percentage']].groupby('location').agg({'death_percentage': 'max','cases_percentage': 'max'}).sort_values(by=['death_percentage'], ascending=False)
# Out:
#                         death_percentage  cases_percentage
# location
# Peru                            0.594968          6.718125
# Bulgaria                        0.450136         10.821098
# Bosnia and Herzegovina          0.415274          8.983093
# North Macedonia                 0.398929         10.666238
# Hungary                         0.393145         12.605364
# ...                                  ...               ...
# Turkmenistan                         NaN               NaN
# Tuvalu                               NaN               NaN
# Vanuatu                              NaN          0.002142
# Vatican                              NaN          3.217822
# Wales                                NaN               NaN
#
# [242 rows x 2 columns]
